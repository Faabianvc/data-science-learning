# %%
import sys
import os

sys.path.append(os.path.abspath(".."))

# %%
import src

# %%
import sys
# !{sys.executable} -m pip install pandas

# %%
from src.data_loader import load_data

# %%
import os
os.listdir("../data")
# Out:
# ['Smartphone_Usage_Productivity_Dataset_50000.csv']

# %%
df = load_data("../data/Smartphone_Usage_Productivity_Dataset_50000.csv")
df.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8             4
# 1                 1.5                        5          6.4             1
# 2                 5.7                        5          9.0             4
# 3                 2.5                        2          5.7             3
# 4                 1.3                        4          5.7             3
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
os.getcwd()
# Out:
# 'c:\\Users\\faval\\Documents\\data-science-learning\\notebooks'

# %%
df.shape, df.columns
# Out:
# ((50000, 13),
#  Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Device_Type',
#         'Daily_Phone_Hours', 'Social_Media_Hours', 'Work_Productivity_Score',
#         'Sleep_Hours', 'Stress_Level', 'App_Usage_Count',
#         'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours'],
#        dtype='str'))

# %%
df.info
# Out:
# <bound method DataFrame.info of       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0          U1   58    Male    Professional     Android                1.3
# 1          U2   25    Male    Professional     Android                1.2
# 2          U3   19    Male         Student         iOS                5.3
# 3          U4   35  Female  Business Owner         iOS                5.8
# 4          U5   33    Male      Freelancer     Android                7.9
# ...       ...  ...     ...             ...         ...                ...
# 49995  U49996   44    Male  Business Owner     Android                5.9
# 49996  U49997   42   Other  Business Owner     Android                2.9
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0          U1   58    Male    Professional     Android                1.3
# 1          U2   25    Male    Professional     Android                1.2
# 2          U3   19    Male         Student         iOS                5.3
# 3          U4   35  Female  Business Owner         iOS                5.8
# 4          U5   33    Male      Freelancer     Android                7.9
# ...       ...  ...     ...             ...         ...                ...
# 49995  U49996   44    Male  Business Owner     Android                5.9
# 49996  U49997   42   Other  Business Owner     Android                2.9
# 49997  U49998   27  Female      Freelancer         iOS                1.4
# 49998  U49999   41  Female  Business Owner         iOS                8.9
# 49999  U50000   46   Other      Freelancer     Android                8.8
#
# ...

# %%
df.isna().sum().sort_values(ascending=False).head(20)
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50000 non-null  str
#  1   Age                        50000 non-null  int64
#  2   Gender                     50000 non-null  str
#  3   Occupation                 50000 non-null  str
#  4   Device_Type                50000 non-null  str
#  5   Daily_Phone_Hours          50000 non-null  float64
#  6   Social_Media_Hours         50000 non-null  float64
#  7   Work_Productivity_Score    50000 non-null  int64
#  8   Sleep_Hours                50000 non-null  float64
#  9   Stress_Level               50000 non-null  int64
#  10  App_Usage_Count            50000 non-null  int64
#  11  Caffeine_Intake_Cups       50000 non-null  int64
#  12  Weekend_Screen_Time_Hours  50000 non-null  float64
# dtypes: float64(4), int64(5), str(4)
# ...

# %%
list(df.select_dtypes(include="str").columns)
# Out:
# ['User_ID', 'Gender', 'Occupation', 'Device_Type']

# %%
df.select_dtypes(include="str").info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   User_ID      50000 non-null  str
#  1   Gender       50000 non-null  str
#  2   Occupation   50000 non-null  str
#  3   Device_Type  50000 non-null  str
# dtypes: str(4)
# memory usage: 1.5 MB

# %%
df.select_dtypes(include="str").dtypes
# Out:
# User_ID        str
# Gender         str
# Occupation     str
# Device_Type    str
# dtype: object

# %%
prom_hd = df["Sleep_Hours"].mean()
med_hd  = df["Sleep_Hours"].median()
std_hd  = df["Sleep_Hours"].std()
min_hd  = df["Sleep_Hours"].min()
max_hd  = df["Sleep_Hours"].max()

print(f"""
Promedio: {prom_hd:.2f}
Mediana: {med_hd:.2f}
Desviación estándar: {std_hd:.2f}
Mínimo: {min_hd}
Máximo: {max_hd}
""")
# Out:
# Promedio: 6.50
# Mediana: 6.50
# Desviación estándar: 1.45
# Mínimo: 4.0
# Máximo: 9.0

# %%
print(f"Doble del promedio: {prom_hd * 2:.2f}")
# Out:
# Doble del promedio: 13.00
